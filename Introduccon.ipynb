# %% [markdown]
# <a href="https://colab.research.google.com/github/antvilla06/Signal-and-image-processing/blob/main/Introduccon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
imagen = cv2.imread("/content/imagen.jpg")
plt.imshow(imagen)

# %%
print('Esta imagen es:', type(imagen))
print('Dimensiones:', imagen.shape)
# Out:
# Esta imagen es: <class 'numpy.ndarray'>
# Dimensiones: (205, 246, 3)
